# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/VEDANARAYANAN/Downloads/diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.columns = df.columns.str.lower()

# %%
df
# Out:
#      pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      diabetespedigreefunction  age  outcome
# 0                       0.627   50        1
# ...

# %%
independent = df.drop('outcome',axis='columns')

# %%
independent
# Out:
#      pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      diabetespedigreefunction  age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
dependent = df['outcome']

# %%
dependent
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: outcome, Length: 768, dtype: int64

# %%
from sklearn import tree
decision = tree.DecisionTreeClassifier()

# %%
decision.fit(independent, dependent)
# Out:
# DecisionTreeClassifier()

# %%
decision.score(independent, dependent)
# Out:
# 1.0

# %%
from sklearn import tree
import matplotlib.pyplot as plt
fig = fig = plt.figure(figsize=(100,50))
print(tree.plot_tree((decision),filled=1))
# Out:
# [Text(0.48527405753968256, 0.9642857142857143, 'X[1] <= 127.5\ngini = 0.454\nsamples = 768\nvalue = [500, 268]'), Text(0.20616319444444445, 0.8928571428571429, 'X[7] <= 28.5\ngini = 0.313\nsamples = 485\nvalue = [391, 94]'), Text(0.10863095238095238, 0.8214285714285714, 'X[5] <= 45.4\ngini = 0.155\nsamples = 271\nvalue = [248, 23]'), Text(0.07242063492063493, 0.75, 'X[5] <= 30.95\ngini = 0.139\nsamples = 267\nvalue = [247, 20]'), Text(0.023809523809523808, 0.6785714285714286, 'X[0] <= 7.5\ngini = 0.026\nsamples = 151\nvalue = [149, 2]'), Text(0.015873015873015872, 0.6071428571428571, 'X[6] <= 0.672\ngini = 0.013\nsamples = 150\nvalue = [149, 1]'), Text(0.007936507936507936, 0.5357142857142857, 'gini = 0.0\nsamples = 131\nvalue = [131, 0]'), Text(0.023809523809523808, 0.5357142857142857, 'X[6] <= 0.686\ngini = 0.1\nsamples = 19\nvalue = [18, 1]'), Text(0.015873015873015872, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'), Text(0.031746031746031744, 0.4642857142857143, '
# ...

# %%
df.tail()
# Out:
#      pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      diabetespedigreefunction  age  outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
pregnencies = int(input("Enter no of pregnencies you had: "))
glucose = int(input("Enter your glucose level: "))
blood_pressure = int(input("Enter your blood pressure level: "))
skinthickness = int(input("Enter your skin thickness: "))
insulin = int(input("Enter your insulin level: "))
bmi = float(input("Enter your bmi value: "))
diabetespedigreefunction = float(input("Enter your diabetes pedigree function: "))
age = int(input("Enter your age: "))
diabetes = decision.predict([[pregnencies, glucose,blood_pressure, skinthickness, insulin, bmi, diabetespedigreefunction, age]])
if diabetes == [0]:
    print("You are not diabetic")
if diabetes == [1]:
    print("You are diabetic")
# Out:
# You are not diabetic
# c:\Users\VEDANARAYANAN\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
